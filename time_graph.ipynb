# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Model/Tool_Prediction.csv')

# %%
next_time = data['next_time']
predicted_time = data['predicted_next_time']

data['time difference'] = next_time - predicted_time
print(data['time difference'].head())
# Out:
# 0       -0.173136
# 1       16.226448
# 2    -9012.256661
# 3    28894.467580
# 4     -512.284161
# Name: time difference, dtype: float64

# %%
print(data['time difference'].head())
# Out:
# 0       -0.173136
# 1       16.226448
# 2    -9012.256661
# 3    28894.467580
# 4     -512.284161
# Name: time difference, dtype: float64

# %%
#plot data

import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
fig = plt.figure()
ax = plt.axes()
# Out:
# C:\Users\Cristian\AppData\Local\Temp\ipykernel_14088\249504432.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
data_to_plot = data['time difference'][1000:]
#remove nan values
data_to_plot = data_to_plot.dropna()
#remove outliers from data
#data_to_plot = data_to_plot[data_to_plot.between(data_to_plot.quantile(.5), data_to_plot.quantile(.95))]

print(data_to_plot)

# plot normally
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.axhline(y=0, color='orange', linestyle='-', zorder=2)
plt.plot(data_to_plot, zorder=1)
plt.legend(['Truth value',], loc='lower right', )

plt.title('Time difference between predicted time and actual time')
plt.xlabel('Entries')
plt.ylabel('Time difference')
plt.show()
#draw a orange line at 0 on top of the plot
# Out:
# 1000    -126272.41550
# 1001     -45064.62522
# 1002    -103970.95410
# 1003     -47242.65644
# 1004    -863169.20206
#              ...
# 85969    -25574.62303
# 85970   -126158.94950
# 85971    -43832.54522
# 85972    381823.20090
# 85973    -47228.64744
# Name: time difference, Length: 84973, dtype: float64
# c:\Users\Cristian\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import sns

sns.distplot(data['time difference'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = 'Time difference')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Cristian\Desktop\Q3\ProcessMining\ProcessMining\time_graph.ipynb Cell 6 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/time_graph.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> import sns
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/time_graph.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> sns.distplot(data['time difference'], hist = False, kde = True,
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/time_graph.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>                  kde_kws = {'linewidth': 3},
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/time_graph.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a>                  label = 'Time difference')
#
# ...

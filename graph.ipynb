# %%
import pandas as pd
import numpy as np

data = pd.read_csv('complete_test_data.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\Cristian\AppData\Local\Temp\ipykernel_22172\2414357448.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
fig = plt.figure()
ax = plt.axes()

# %%
next_data = data['Next Event number']
predicted_data = data['Predicted Event number']
#make two line plots on the same axes

# %%
#plt.figure(figsize = (55,15))
unique_activities = data['concept:name'].unique()
for i in unique_activities:
    data[i] = [1 if x == i else 0 for x in data['concept:name']]
dictionary = {unique_activities[i]: i for i in range(unique_activities.size)}

x_ticks = np.arange(1, 21)
#unique entries in the data set
unique_entries = data['concept:name'].unique()
print(unique_entries)
print(unique_entries.size)
# tick_labels = ['None','A_SUBMITTED', 'A_PARTLYSUBMITTED', 'W_Afhandelen leads', 'A_DECLINED',
#  'A_PREACCEPTED', 'W_Completeren aanvraag', 'A_ACCEPTED', 'O_SELECTED',
#  'A_FINALIZED', 'O_CREATED', 'O_SENT', 'W_Nabellen offertes', 'A_CANCELLED',
#  'O_CANCELLED', 'O_SENT_BACK', 'W_Valideren aanvraag', 'O_ACCEPTED',
#  'A_REGISTERED', 'A_ACTIVATED', 'A_APPROVED', 'O_DECLINED',
#  'W_Nabellen incomplete dossiers' ,'W_Beoordelen fraude']

plt.hist(next_data, bins=22, range = (-1, 22),alpha=0.5, label='Next event', color='blue')
plt.hist(predicted_data, bins=22,range = (-1, 22),alpha=0.5, label='Predicted event', color= 'red')
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True
plt.title('Next event and predicted event')
#plt.xticks(range(24), tick_labels)
plt.xticks([])
plt.legend()
plt.xlabel('Event Type')
plt.ylabel('Occurences')
plt.show()
plt.savefig('next_event_and_predicted_event.png')
# Out:
# ['A_SUBMITTED' 'A_PARTLYSUBMITTED' 'W_Afhandelen leads' 'A_DECLINED'
#  'A_PREACCEPTED' 'W_Completeren aanvraag' 'A_ACCEPTED' 'O_SELECTED'
#  'A_FINALIZED' 'O_CREATED' 'O_SENT' 'W_Nabellen offertes' 'A_CANCELLED'
#  'O_CANCELLED' 'O_SENT_BACK' 'W_Valideren aanvraag' 'O_ACCEPTED'
#  'A_REGISTERED' 'A_ACTIVATED' 'A_APPROVED' 'O_DECLINED'
#  'W_Nabellen incomplete dossiers' 'W_Beoordelen fraude']
# 23

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate example data
next_data = data['Next Event number']
predicted_data= data['Predicted Event number']
# Create scatter plot
plt.scatter(next_data, predicted_data , alpha=0.5,)
plt.xlabel('Next event number')
plt.ylabel('Predicted event number')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Cristian\Desktop\Q3\ProcessMining\ProcessMining\graph.ipynb Cell 7 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/graph.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/graph.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> # Generate example data
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/graph.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a> next_data = data['Next Event number']
#       <a href='vscode-notebook-cell:/c%3A/Users/Cristian/Desktop/Q3/ProcessMining/ProcessMining/graph.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a> predicted_data= data['Predicted Event number']
# ...
